# %% [markdown]
# <h1>CycleGan</h1>
#
# Установка необходимых зависимостей:

# %%
# !pip install -r requirements.txt

# %% [markdown]
# <h2>Создание датасета и обучение сети:</h2>
#
# <h3>Датасет должен иметь данную структуру:</h3>
# <ul>
# <li>Datasetname</li>
# <ul>
#     <li>test
#         <ul>
#             <li>x</li>
#             <li>y</li>
#         </ul>
#     </li>
#     <li>train
#         <ul>
#             <li>x</li>
#             <li>y</li>
#         </ul>
#     </li>
# </ul>
# </ul>
#
# <h3>Обучение сети(аргументы меняются в starttest.py):</h3>

# %%
# !python starttrain.py

# %% [markdown]
# <h3>Генерация изображений(аргументы меняются в starttest.py):</h3>

# %%
# !python starttest.py

# %% [markdown]
# <h3>Также вы можете воспользоваться GUI(прогрессбары не работают)</h3>

# %%
# !python main.py
# Out:
# 64 64 0.002 10
# 0

# %% [markdown]
# <h2>Результаты:</h2>
#
# <h3>Ночь в день Minecraft</h3>

# %%
# %matplotlib inline
from imageshow import *

# %%
show("outputs/minecraftday2night/x/0001.jpg", "Из ночи в день")
show("outputs/minecraftday2night/y/0049.jpg", "Из дня в ночь")

# %% [markdown]
# В папке "outputs/minecraftday2night" есть разные результаты, также там есть графики различных лоссов. Датасет был достаточно маленьким(менее сотни фотографий)

# %% [markdown]
# <h3>Тест horse2zebra</h3>
# Обучение: 100 эпох размер изображения 128px

# %%
show("outputs/horse2zebra/x/0031.jpg", "Из зебры в лошадь")
show("outputs/horse2zebra/y/0021.jpg", "Из лошади в зебру")
